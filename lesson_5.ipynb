# %%
import pandas as pd
import numpy as np

# %%
food_df = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', sep='\t')

# %%
food_df.value_counts()
# Out:
# order_id  quantity  item_name           choice_description                                                                        item_price
# 724       1         Canned Soft Drink   [Coke]                                                                                    $1.25         3
# 926       1         Chicken Bowl        [Roasted Chili Corn Salsa, [Fajita Vegetables, Rice, Cheese, Sour Cream, Lettuce]]        $8.75         3
# 1011      1         Canned Soft Drink   [Coke]                                                                                    $1.25         3
# 103       1         Steak Burrito       [Tomatillo Red Chili Salsa, [Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]  $11.75        2
# 108       1         Canned Soda         [Mountain Dew]                                                                            $1.09         2
# ...

# %%
food_df.value_counts(ascending=True)
# Out:
# order_id  quantity  item_name          choice_description                                                                                                  item_price
# 1         1         Izze               [Clementine]                                                                                                        $3.39         1
#                     Nantucket Nectar   [Apple]                                                                                                             $3.39         1
# 2         2         Chicken Bowl       [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]                                          $16.98        1
# 3         1         Chicken Bowl       [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sour Cream, Guacamole, Lettuce]]                                         $10.98        1
# ...

# %%
food_df.value_counts(ascending=True).head(5)
# Out:
# order_id  quantity  item_name         choice_description                                                                                                  item_price
# 1         1         Izze              [Clementine]                                                                                                        $3.39         1
#                     Nantucket Nectar  [Apple]                                                                                                             $3.39         1
# 2         2         Chicken Bowl      [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]                                          $16.98        1
# 3         1         Chicken Bowl      [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sour Cream, Guacamole, Lettuce]]                                         $10.98        1
# ...

# %%
food_df.value_counts(normalize=True)
# Out:
# order_id  quantity  item_name           choice_description                                                                        item_price
# 724       1         Canned Soft Drink   [Coke]                                                                                    $1.25         0.000889
# 926       1         Chicken Bowl        [Roasted Chili Corn Salsa, [Fajita Vegetables, Rice, Cheese, Sour Cream, Lettuce]]        $8.75         0.000889
# 1011      1         Canned Soft Drink   [Coke]                                                                                    $1.25         0.000889
# 103       1         Steak Burrito       [Tomatillo Red Chili Salsa, [Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]  $11.75        0.000592
# 108       1         Canned Soda         [Mountain Dew]                                                                            $1.09         0.000592
# ...

# %%
food_df["item_name"].value_counts()
# Out:
# item_name
# Chicken Bowl                             726
# Chicken Burrito                          553
# Chips and Guacamole                      479
# Steak Burrito                            368
# Canned Soft Drink                        301
# Chips                                    211
# Steak Bowl                               211
# Bottled Water                            162
# Chicken Soft Tacos                       115
# Chips and Fresh Tomato Salsa             110
# Chicken Salad Bowl                       110
# Canned Soda                              104
# Side of Chips                            101
# Veggie Burrito                            95
# Barbacoa Burrito                          91
# Veggie Bowl                               85
# Carnitas Bowl                             68
# Barbacoa Bowl                             66
# Carnitas Burrito                          59
# Steak Soft Tacos                          55
# 6 Pack Soft Drink                         54
# ...

# %%
food_df["item_name"].value_counts(ascending=True)
# Out:
# item_name
# Chips and Mild Fresh Tomato Salsa          1
# Veggie Crispy Tacos                        1
# Carnitas Salad                             1
# Bowl                                       2
# Crispy Tacos                               2
# Salad                                      2
# Steak Salad                                4
# Burrito                                    6
# Carnitas Salad Bowl                        6
# Veggie Salad                               6
# Carnitas Crispy Tacos                      7
# Veggie Soft Tacos                          7
# Chicken Salad                              9
# Barbacoa Salad Bowl                       10
# Barbacoa Crispy Tacos                     11
# Veggie Salad Bowl                         18
# Chips and Roasted Chili-Corn Salsa        18
# Izze                                      20
# Chips and Tomatillo-Red Chili Salsa       20
# Chips and Roasted Chili Corn Salsa        22
# Barbacoa Soft Tacos                       25
# ...

# %%
food_df["item_name"].value_counts(normalize=True)
# Out:
# item_name
# Chicken Bowl                             0.157075
# Chicken Burrito                          0.119645
# Chips and Guacamole                      0.103635
# Steak Burrito                            0.079619
# Canned Soft Drink                        0.065123
# Chips                                    0.045651
# Steak Bowl                               0.045651
# Bottled Water                            0.035050
# Chicken Soft Tacos                       0.024881
# Chips and Fresh Tomato Salsa             0.023799
# Chicken Salad Bowl                       0.023799
# Canned Soda                              0.022501
# Side of Chips                            0.021852
# Veggie Burrito                           0.020554
# Barbacoa Burrito                         0.019688
# Veggie Bowl                              0.018390
# Carnitas Bowl                            0.014712
# Barbacoa Bowl                            0.014280
# Carnitas Burrito                         0.012765
# ...

# %%
food_df["item_name"].value_counts(normalize=True) * 100
# Out:
# item_name
# Chicken Bowl                             15.707486
# Chicken Burrito                          11.964518
# Chips and Guacamole                      10.363479
# Steak Burrito                             7.961921
# Canned Soft Drink                         6.512332
# Chips                                     4.565123
# Steak Bowl                                4.565123
# Bottled Water                             3.504976
# Chicken Soft Tacos                        2.488100
# Chips and Fresh Tomato Salsa              2.379922
# Chicken Salad Bowl                        2.379922
# Canned Soda                               2.250108
# Side of Chips                             2.185201
# Veggie Burrito                            2.055387
# Barbacoa Burrito                          1.968845
# Veggie Bowl                               1.839031
# Carnitas Bowl                             1.471225
# Barbacoa Bowl                             1.427953
# ...

# %%
food_df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
food_df["choice_description"].value_counts(dropna=False)
# Out:
# choice_description
# NaN                                                                                                   1246
# [Diet Coke]                                                                                            134
# [Coke]                                                                                                 123
# [Sprite]                                                                                                77
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Lettuce]]                                  42
#                                                                                                       ...
# [Tomatillo Red Chili Salsa, [Rice, Fajita Vegetables, Black Beans, Sour Cream, Cheese, Guacamole]]       1
# [Roasted Chili Corn Salsa, [Rice, Sour Cream, Cheese, Lettuce, Guacamole]]                               1
# ...

# %%
food_df["item_name"].value_counts()["Chicken Bowl"]
# Out:
# np.int64(726)

# %%
food_df.groupby("item_name").size()
# Out:
# item_name
# 6 Pack Soft Drink                         54
# Barbacoa Bowl                             66
# Barbacoa Burrito                          91
# Barbacoa Crispy Tacos                     11
# Barbacoa Salad Bowl                       10
# Barbacoa Soft Tacos                       25
# Bottled Water                            162
# Bowl                                       2
# Burrito                                    6
# Canned Soda                              104
# Canned Soft Drink                        301
# Carnitas Bowl                             68
# Carnitas Burrito                          59
# Carnitas Crispy Tacos                      7
# Carnitas Salad                             1
# Carnitas Salad Bowl                        6
# Carnitas Soft Tacos                       40
# Chicken Bowl                             726
# Chicken Burrito                          553
# Chicken Crispy Tacos                      47
# Chicken Salad                              9
# ...

# %%
food_df.groupby("item_name").count()
# Out:
#                                        order_id  quantity  choice_description  \
# item_name
# 6 Pack Soft Drink                            54        54                  54
# Barbacoa Bowl                                66        66                  66
# Barbacoa Burrito                             91        91                  91
# Barbacoa Crispy Tacos                        11        11                  11
# Barbacoa Salad Bowl                          10        10                  10
# Barbacoa Soft Tacos                          25        25                  25
# Bottled Water                               162       162                   0
# Bowl                                          2         2                   2
# Burrito                                       6         6                   6
# Canned Soda                                 104       104                 104
# Canned Soft Drink                           301       301                 301
# ...
