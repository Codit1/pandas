# %%
import pandas as pd

# %%
my_df = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', sep='\t')

my_df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
my_df[my_df == "Chicken Salad Bowl"]
# Out:
#       order_id  quantity           item_name choice_description item_price
# 0          NaN       NaN                 NaN                NaN        NaN
# 1          NaN       NaN                 NaN                NaN        NaN
# 2          NaN       NaN                 NaN                NaN        NaN
# 3          NaN       NaN                 NaN                NaN        NaN
# 4          NaN       NaN                 NaN                NaN        NaN
# ...        ...       ...                 ...                ...        ...
# 4617       NaN       NaN                 NaN                NaN        NaN
# 4618       NaN       NaN                 NaN                NaN        NaN
# 4619       NaN       NaN  Chicken Salad Bowl                NaN        NaN
# 4620       NaN       NaN  Chicken Salad Bowl                NaN        NaN
# 4621       NaN       NaN  Chicken Salad Bowl                NaN        NaN
#
# [4622 rows x 5 columns]

# %%
my_df[my_df == "Chicken Salad Bowl"].count()
# Out:
# order_id                0
# quantity                0
# item_name             110
# choice_description      0
# item_price              0
# dtype: int64

# %%
my_df[my_df["quantity"] > 4]
# Out:
#       order_id  quantity                     item_name choice_description  \
# 2441       970         5                 Bottled Water                NaN
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
# 3599      1443         7                 Bottled Water                NaN
# 3887      1559         8                 Side of Chips                NaN
# 4152      1660        10                 Bottled Water                NaN
#
#      item_price
# 2441     $7.50
# 3598    $44.25
# 3599    $10.50
# 3887    $13.52
# 4152    $15.00

# %%
my_df[my_df["quantity"] > 4]["item_name"]
# Out:
# 2441                   Bottled Water
# 3598    Chips and Fresh Tomato Salsa
# 3599                   Bottled Water
# 3887                   Side of Chips
# 4152                   Bottled Water
# Name: item_name, dtype: str

# %%
my_df[(my_df["quantity"] > 4) | (my_df["quantity"] < 2)]
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 5            3         1                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
len(my_df[(my_df["quantity"] > 4) | (my_df["quantity"] < 2)])
# Out:
# 4360

# %%
my_df[(my_df["quantity"] < 2) & (my_df["order_id"] < 30)]
# Out:
#     order_id  quantity                              item_name  \
# 0          1         1           Chips and Fresh Tomato Salsa
# 1          1         1                                   Izze
# 2          1         1                       Nantucket Nectar
# 3          1         1  Chips and Tomatillo-Green Chili Salsa
# 5          3         1                           Chicken Bowl
# ..       ...       ...                                    ...
# 61        28         1                       Steak Soft Tacos
# 62        28         1                            Veggie Bowl
# 63        28         1                        Chicken Burrito
# 64        29         1                          Steak Burrito
# 65        29         1                       Steak Soft Tacos
#
#                                    choice_description item_price
# 0                                                 NaN     $2.39
# 1                                        [Clementine]     $3.39
# ...
