# %%
import pandas as pd

# %%
my_df = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', sep='\t')

my_df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
my_df = my_df.head(50)
my_df["quantity"] = my_df["quantity"].apply(lambda x: f"NO. {x}")
my_df
# Out:
#     order_id   quantity                              item_name  \
# 0          1  NO. NO. 1           Chips and Fresh Tomato Salsa
# 1          1  NO. NO. 1                                   Izze
# 2          1  NO. NO. 1                       Nantucket Nectar
# 3          1  NO. NO. 1  Chips and Tomatillo-Green Chili Salsa
# 4          2  NO. NO. 2                           Chicken Bowl
# 5          3  NO. NO. 1                           Chicken Bowl
# 6          3  NO. NO. 1                          Side of Chips
# 7          4  NO. NO. 1                          Steak Burrito
# 8          4  NO. NO. 1                       Steak Soft Tacos
# 9          5  NO. NO. 1                          Steak Burrito
# 10         5  NO. NO. 1                    Chips and Guacamole
# 11         6  NO. NO. 1                   Chicken Crispy Tacos
# 12         6  NO. NO. 1                     Chicken Soft Tacos
# 13         7  NO. NO. 1                           Chicken Bowl
# ...
