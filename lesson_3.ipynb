# %%
import numpy as np
import pandas as pd
from numpy.random import randn
import string

# %%
my_data = randn(4, 5)

rows = np.random.choice(list(string.ascii_uppercase), 4)
cols = ['Monday', 'Tuesday', 'Wednesday', 'wednesday', 'Friday']

df = pd.DataFrame(my_data, rows, cols)
df
# Out:
#      Monday   Tuesday  Wednesday  wednesday    Friday
# N  1.076788  0.109067  -0.386394   0.231425 -0.051619
# Q -0.097087 -0.959122   0.700408  -0.298331 -0.421391
# V -0.710587 -1.764096   0.970947  -0.226128 -0.845695
# Q -0.700313 -0.412704  -1.283072  -0.874482  0.970803

# %%
df.loc[["N", "Q"]]
# Out:
#      Monday   Tuesday  Wednesday  wednesday    Friday
# N  1.076788  0.109067  -0.386394   0.231425 -0.051619
# Q -0.097087 -0.959122   0.700408  -0.298331 -0.421391
# Q -0.700313 -0.412704  -1.283072  -0.874482  0.970803

# %%
geo_df = pd.read_csv("geoservices.csv")
geo_df
# Out:
#                                              Address            City  \
# 0      3666 21st St,  San Francisco,  CA 94114,  USA   San Francisco
# 1    735 Dolores St,  San Francisco,  CA 94119,  USA   San Francisco
# 2  332 Hill St,  San Francisco,  California 94114...   San Francisco
# 3      3995 23rd St,  San Francisco,  CA 94114,  USA   San Francisco
# 4  1056 Sanchez St,  San Francisco,  California, ...   San Francisco
# 5   551 Alvarado St,  San Francisco,  CA 94114,  USA   San Francisco
#
#                State Country          Name  Employees  \
# 0           CA 94114     USA       Madeira          8
# 1           CA 94119     USA   Bready Shop         15
# 2   California 94114     USA   Super River         25
# 3           CA 94114     USA    Ben's Shop         10
# 4         California     USA       Sanchez         12
# 5           CA 94114     USA    Richvalley         20
#
#                                          Coordinates   Latitude   Longitude  \
# ...

# %%
geo_df["Address"]
# Out:
# 0        3666 21st St,  San Francisco,  CA 94114,  USA
# 1      735 Dolores St,  San Francisco,  CA 94119,  USA
# 2    332 Hill St,  San Francisco,  California 94114...
# 3        3995 23rd St,  San Francisco,  CA 94114,  USA
# 4    1056 Sanchez St,  San Francisco,  California, ...
# 5     551 Alvarado St,  San Francisco,  CA 94114,  USA
# Name: Address, dtype: str

# %%
geo_df.loc[[0, 3]]
# Out:
#                                          Address            City      State  \
# 0  3666 21st St,  San Francisco,  CA 94114,  USA   San Francisco   CA 94114
# 3  3995 23rd St,  San Francisco,  CA 94114,  USA   San Francisco   CA 94114
#
#   Country         Name  Employees  \
# 0     USA      Madeira          8
# 3     USA   Ben's Shop         10
#
#                                          Coordinates   Latitude   Longitude  \
# 0  3666, 21st Street, Noe Valley, San Francisco, ...  37.756650 -122.429405
# 3  3995, 23rd Street, Noe Valley, San Francisco, ...  37.752965 -122.431714
#
#    ID
# 0   1
# 3   4
