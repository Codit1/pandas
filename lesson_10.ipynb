# %%
import pandas as pd

# %%
my_df = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', sep='\t')

my_df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
new_column = my_df["quantity"]

# %%
my_df.set_index(new_column, inplace=True)
my_df
# Out:
#           order_id  quantity                              item_name  \
# quantity
# 1                1         1           Chips and Fresh Tomato Salsa
# 1                1         1                                   Izze
# 1                1         1                       Nantucket Nectar
# 1                1         1  Chips and Tomatillo-Green Chili Salsa
# 2                2         2                           Chicken Bowl
# ...            ...       ...                                    ...
# 1             1833         1                          Steak Burrito
# 1             1833         1                          Steak Burrito
# 1             1834         1                     Chicken Salad Bowl
# 1             1834         1                     Chicken Salad Bowl
# 1             1834         1                     Chicken Salad Bowl
#
#                                          choice_description item_price
# quantity
# ...

# %%
my_df.drop("quantity", axis=1, inplace=True)
my_df.reset_index(inplace=True)
my_df
# Out:
#       index  order_id                              item_name  \
# 0         0         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         2         1                       Nantucket Nectar
# 3         3         1  Chips and Tomatillo-Green Chili Salsa
# 4         4         2                           Chicken Bowl
# ...     ...       ...                                    ...
# 4617   4617      1833                          Steak Burrito
# 4618   4618      1833                          Steak Burrito
# 4619   4619      1834                     Chicken Salad Bowl
# 4620   4620      1834                     Chicken Salad Bowl
# 4621   4621      1834                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# 1                                          [Clementine]     $3.39
# ...

# %%
my_df["quantity"] = new_column
my_df
# Out:
#       index  order_id                              item_name  \
# 0         0         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         2         1                       Nantucket Nectar
# 3         3         1  Chips and Tomatillo-Green Chili Salsa
# 4         4         2                           Chicken Bowl
# ...     ...       ...                                    ...
# 4617   4617      1833                          Steak Burrito
# 4618   4618      1833                          Steak Burrito
# 4619   4619      1834                     Chicken Salad Bowl
# 4620   4620      1834                     Chicken Salad Bowl
# 4621   4621      1834                     Chicken Salad Bowl
#
#                                      choice_description item_price  quantity
# 0                                                   NaN     $2.39          1
# 1                                          [Clementine]     $3.39          1
# ...
